# %% [markdown]
# <a href="https://colab.research.google.com/github/eumichelemelo/Phyton_Pandas/blob/main/Primeiro_Exemplo_em_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando biblioteca pandas no Python
import pandas as pd

combustiveis_df = pd.read_excel("ca-2021-02.xlsx")

display(combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#Exibe as primeiros linhas. para definir a quantidade, coloca a quantidade entre aspas ()
display(combustiveis_df.head(2))
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep   Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 0  57302-605  GASOLINA     2021-11-01           6.799              NaN
# 1  57302-605    ETANOL     2021-11-01           5.299              NaN
#
#   Unidade de Medida       Bandeira
# 0        R$ / litro  VIBRA ENERGIA
# 1        R$ / litro  VIBRA ENERGIA

# %%
# comandos Dataframe.shape- SHAPE mostra a quantidade de linhas x colunas e Dataframe.describle() abre parentes porque é uma função
print(combustiveis_df.shape)
# Out:
# (168409, 16)

# %%
# describe() mostra estatisticas mais básicas e racional de acordo com os dados numéricos
print(combustiveis_df.describe())
# Out:
#        Valor de Venda  Valor de Compra
# count   168409.000000              0.0
# mean         6.005184              NaN
# std          0.794541              NaN
# min          2.849000              NaN
# 25%          5.339000              NaN
# 50%          5.859000              NaN
# 75%          6.699000              NaN
# max          8.990000              NaN

# %%
# info() exibe nomes das colunas, non-null Count- identifica as linhas da coluna que estão preenchidas e o Dtype - tipo de caracter tem nas colunas
print(combustiveis_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
# ...

# %%
#Filtrar apenas uma coluna desejada
display(combustiveis_df['Revenda'])
# Out:
# 0                               POSTO ARAPIRACA LTDA
# 1                               POSTO ARAPIRACA LTDA
# 2                               POSTO ARAPIRACA LTDA
# 3                               POSTO ARAPIRACA LTDA
# 4                               POSTO ARAPIRACA LTDA
#                              ...
# 168404    COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168405             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168406             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168407             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168408             ABC DISTRIBUICAO DE PETROLEO LTDA
# Name: Revenda, Length: 168409, dtype: object

# %%
#Aqui criamos um novo dataframe apenas com as colunas desejadas 
ca_df = combustiveis_df[['Revenda','Municipio','Produto','Valor de Venda']]
display(ca_df)
# Out:
#                                            Revenda  Municipio  \
# 0                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 1                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 2                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 3                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 4                             POSTO ARAPIRACA LTDA  ARAPIRACA
# ...                                            ...        ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA     JEQUIE
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
#
#                    Produto  Valor de Venda
# 0                 GASOLINA           6.799
# 1                   ETANOL           5.299
# 2                   DIESEL           5.549
# 3       GASOLINA ADITIVADA           6.899
# ...

# %%
#Exibe a 4ª linha. - primeira linha é 0
display(ca_df.loc[3])
# Out:
# Revenda           POSTO ARAPIRACA LTDA
# Municipio                    ARAPIRACA
# Produto             GASOLINA ADITIVADA
# Valor de Venda                   6.899
# Name: 3, dtype: object

# %% [markdown]
# # Nova seção

# %%
# Criar um dataframe gas_df contendo apenas 4 colunas(Revenda, Municipio,Produto, Valor de Venda) somente com combustível: GASOLINA.
gas_df = ca_df.loc[ca_df['Produto'] == 'GASOLINA']
display(gas_df['Valor de Venda'].max()) 
# ['Coluna desejada'].max(valor máximo))
# Out:
# 7.999

# %%
# Importando biblioteca pandas no Python
import pandas as pd

combustiveis_df = pd.read_excel("ca-2021-02.xlsx")

display(combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
# Qual a média de preços dos combustíveis GASOLINA e GASOLINA ADITIVADA do Bairro MOOCA em SÃO PAULO?
display(combustiveis_df.loc[(combustiveis_df['Bairro'] == 'MOOCA') & (combustiveis_df['Municipio'] == 'SAO PAULO') & ((combustiveis_df['Produto'] == 'GASOLINA') | (combustiveis_df['Produto'] == 'GASOLINA ADITIVADA'))])
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 11590              SE             SP  SAO PAULO
# 11646              SE             SP  SAO PAULO
# 11648              SE             SP  SAO PAULO
# 11834              SE             SP  SAO PAULO
# 11836              SE             SP  SAO PAULO
# 13271              SE             SP  SAO PAULO
# 13342              SE             SP  SAO PAULO
# 13344              SE             SP  SAO PAULO
# 13730              SE             SP  SAO PAULO
# 13733              SE             SP  SAO PAULO
# 63246              SE             SP  SAO PAULO
# 63248              SE             SP  SAO PAULO
# 63300              SE             SP  SAO PAULO
# 63302              SE             SP  SAO PAULO
# 63341              SE             SP  SAO PAULO
# 63343              SE             SP  SAO PAULO
# 63345              SE             SP  SAO PAULO
# 63347              SE             SP  SAO PAULO
# ...

# %%
display(combustiveis_df.loc[(combustiveis_df['Bairro'] == 'MOOCA') &
                            (combustiveis_df['Municipio'] == 'SAO PAULO') &
                            ((combustiveis_df['Produto'] == 'GASOLINA') | (combustiveis_df['Produto'] == 'GASOLINA ADITIVADA')),['Valor de Venda']].mean())
# Out:
# Valor de Venda    6.575596
# dtype: float64

# %%
# Como mostrar media com valor de venda POR COMBUSTIVEL Brasil todo
display(ca_df['Valor de Venda'])
# Out:
# 0         6.799
# 1         5.299
# 2         5.549
# 3         6.899
# 4         5.649
#           ...
# 168404    5.859
# 168405    6.580
# 168406    4.740
# 168407    5.448
# 168408    6.580
# Name: Valor de Venda, Length: 168409, dtype: float64

# %%
# Quero adicionar uma coluna de valor booleano no combustiveis_df 
# Chamada "Ativo" que, por padrão, vai ser True para 
# TODAS as linhas
combustiveis_df['Ativo'] = True
print(combustiveis_df.info())
display(combustiveis_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
# ...

# %%
# Como mostrar média de valor de venda POR COMBUSTÍVEL Brasil todo?
media_por_combustivel_df = ca_df[['Produto', 'Valor de Venda']].groupby(by='Produto').mean().round(2)
display(media_por_combustivel_df)
# Out:
#                     Valor de Venda
# Produto
# DIESEL                        5.38
# DIESEL S10                    5.45
# ETANOL                        5.46
# GASOLINA                      6.71
# GASOLINA ADITIVADA            6.86
# GNV                           4.39

# %%
#Quero adicionar uma coluna de valor booleano no combustiveis_df
#Chamada busca 'Ativo' que, por padrão, vai ser True para todas as linhas
combustiveis_df['Ativo'] = True
print(combustiveis_df.info())
display(combustiveis_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
# ...

# %%
#passo 21
etanol_indaiatuba_df = combustiveis_df.loc[((combustiveis_df['Municipio'] == 'INDAIATUBA') & (combustiveis_df["Produto"] == "ETANOL"))]

# %%
# Exportar para Excel o dataframe com etanol em Indaiatuba....
etanol_indaiatuba_df.to_excel('etanol_indaiatuba.xlsx', sheet_name='Etanol em Indaiatuba')
